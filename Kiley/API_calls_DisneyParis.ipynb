# %%
#import libraries
import requests
import json
import csv
from pprint import pprint
import pandas as pd

# %%
# Set url for API
url = "https://queue-times.com/parks/4/queue_times.json"

# %%
#check connection
print(requests.get(url))
# Out:
# <Response [200]>

# %%
print(requests.get(url).json())
# Out:
# {'lands': [{'id': 17, 'name': 'Adventureland', 'rides': [{'id': 2702, 'name': 'Adventure Isle', 'is_open': False, 'wait_time': 0, 'last_updated': '2025-01-22T23:00:08.000Z'}, {'id': 7306, 'name': 'Indiana Jones and the Temple of Peril Single Rider', 'is_open': True, 'wait_time': 0, 'last_updated': '2025-01-22T23:00:08.000Z'}, {'id': 2, 'name': 'Indiana Jones™ and the Temple of Peril', 'is_open': True, 'wait_time': 5, 'last_updated': '2025-01-22T23:00:08.000Z'}, {'id': 1, 'name': 'La Cabane des Robinson', 'is_open': True, 'wait_time': 5, 'last_updated': '2025-01-22T23:00:08.000Z'}, {'id': 2703, 'name': "Le Passage Enchanté d'Aladdin", 'is_open': False, 'wait_time': 0, 'last_updated': '2025-01-22T23:00:08.000Z'}, {'id': 2705, 'name': 'Pirate Galleon', 'is_open': False, 'wait_time': 0, 'last_updated': '2025-01-22T23:00:08.000Z'}, {'id': 3, 'name': 'Pirates of the Caribbean', 'is_open': False, 'wait_time': 0, 'last_updated': '2025-01-22T23:00:08.000Z'}, {'id': 2704, 'name': "Pirates' Beach", 'is_open': False, 'wait_time': 0, 'last_updated': '2025-01-22T23:00:08.000Z'}]}, {'id': 18, 'name': 'Discoveryland', 'rides': [{'id': 4, 'name': 'Autopia, presented by Avis', 'is_open': False, 'wait_time': 0, 'last_updated': '2025-01-22T23:00:08.000Z'}, {'id': 5, 'name': 'Buzz Lightyear Laser Blast', 'is_open': True, 'wait_time': 5, 'last_updated': '2025-01-22T23:00:08.000Z'}, {'id': 2706, 'name': 'Disneyland Railroad Discoveryland Station', 'is_open': False, 'wait_time': 0, 'last_updated': '2025-01-22T23:00:08.000Z'}, {'id': 6, 'name': 'Les Mystères du Nautilus', 'is_open': False, 'wait_time': 0, 'last_updated': '2025-01-22T23:00:08.000Z'}, {'id': 2707, 'name': 'Mickey’s PhilharMagic', 'is_open': False, 'wait_time': 0, 'last_updated': '2025-01-22T23:00:08.000Z'}, {'id': 7, 'name': 'Orbitron®', 'is_open': True, 'wait_time': 5, 'last_updated': '2025-01-22T23:00:08.000Z'}, {'id': 9, 'name': 'Star Tours: The Adventures Continue*', 'is_open': True, 'wait_time': 5, 'last_updated': '2025-01-22T23:00:08.000Z'}, {'id': 8, 'name': 'Star Wars Hyperspace Mountain', 'is_open': True, 'wait_time': 5, 'last_updated': '2025-01-22T23:00:08.000Z'}, {'id': 7278, 'name': 'Star Wars Hyperspace Mountain Single Rider', 'is_open': True, 'wait_time': 0, 'last_updated': '2025-01-22T23:00:08.000Z'}, {'id': 4573, 'name': 'Welcome to Starport: A Star Wars Encounter', 'is_open': False, 'wait_time': 0, 'last_updated': '2025-01-22T23:00:08.000Z'}]}, {'id': 19, 'name': 'Fantasyland', 'rides': [{'id': 19, 'name': '"it\'s a small world"', 'is_open': False, 'wait_time': 0, 'last_updated': '2025-01-22T23:00:08.000Z'}, {'id': 14, 'name': "Alice's Curious Labyrinth", 'is_open': False, 'wait_time': 0, 'last_updated': '2025-01-22T23:00:08.000Z'}, {'id': 15, 'name': 'Blanche-Neige et les Sept Nains®', 'is_open': False, 'wait_time': 0, 'last_updated': '2025-01-22T23:00:08.000Z'}, {'id': 17, 'name': 'Casey Jr. – le Petit Train du Cirque', 'is_open': False, 'wait_time': 0, 'last_updated': '2025-01-22T23:00:08.000Z'}, {'id': 11, 'name': 'Disneyland Railroad', 'is_open': False, 'wait_time': 0, 'last_updated': '2025-01-22T23:00:08.000Z'}, {'id': 2711, 'name': 'Disneyland Railroad Fantasyland Station', 'is_open': False, 'wait_time': 0, 'last_updated': '2025-01-22T23:00:08.000Z'}, {'id': 18, 'name': 'Dumbo the Flying Elephant', 'is_open': False, 'wait_time': 0, 'last_updated': '2025-01-22T23:00:08.000Z'}, {'id': 2710, 'name': 'La Tanière du Dragon', 'is_open': False, 'wait_time': 0, 'last_updated': '2025-01-22T23:00:08.000Z'}, {'id': 16, 'name': 'Le Carrousel de Lancelot ', 'is_open': False, 'wait_time': 0, 'last_updated': '2025-01-22T23:00:08.000Z'}, {'id': 21, 'name': 'Le Pays des Contes de Fées, presented by Vittel', 'is_open': False, 'wait_time': 0, 'last_updated': '2025-01-22T23:00:08.000Z'}, {'id': 23, 'name': 'Les Voyages de Pinocchio', 'is_open': False, 'wait_time': 0, 'last_updated': '2025-01-22T23:00:08.000Z'}, {'id': 20, 'name': "Mad Hatter's Tea Cups", 'is_open': False, 'wait_time ...

# %%
# Pretty Print the output of the JSON
response = requests.get(url).json()
print(json.dumps(response, indent=4, sort_keys=True))
# Out:
# {
#     "lands": [
#         {
#             "id": 17,
#             "name": "Adventureland",
#             "rides": [
#                 {
#                     "id": 2702,
#                     "is_open": false,
#                     "last_updated": "2025-01-22T23:00:08.000Z",
#                     "name": "Adventure Isle",
#                     "wait_time": 0
#                 },
#                 {
#                     "id": 7306,
#                     "is_open": true,
#                     "last_updated": "2025-01-22T23:00:08.000Z",
#                     "name": "Indiana Jones and the Temple of Peril Single Rider",
#                     "wait_time": 0
#                 },
#                 {
#                     "id": 2,
#                     "is_open": true,
#                     "last_updated": "2025-01-22T23:00:08.000Z",
#                     "name": "Indiana Jones\u2122 and the Temple of Peril",
#                     "wait_time": 5
#                 },
#                 {
#                     "id": 1,
#                     "is_open": true,
#                     "last_updated": "2025-01-22T23:00:08.000Z",
#                     "name": "La Cabane des Robinson",
#                     "wait_time": 5
#                 },
#                 {
#                     "id": 2703,
#                     "is_open": false,
#                     "last_updated": "2025-01-22T23:00:08.000Z",
#                     "name": "Le Passage Enchant\u00e9 d'Aladdin",
#                     "wait_time": 0
#                 },
#                 {
#                     "id": 2705,
#                     "is_open": false,
#                     "last_updated": "2025-01-22T23:00:08.000Z",
#                     "name": "Pirate Galleon",
#                     "wait_time": 0
#                 },
#                 {
#                     "id": 3,
#                     "is_open": false,
#                     "last_updated": "2025-01-22T23:00:08.000Z",
#                     "name": "Pirates of the Caribbean",
#                     "wait_time": 0
#                 },
#                 {
#                     "id": 2704,
#                     "is_open": false,
#                     "last_updated": "2025-01-22T23:00:08.000Z",
#                     "name": "Pirates' Beach",
#                     "wait_time": 0
#                 }
#             ]
#         },
#         {
#             "id": 18,
#             "name": "Discoveryland",
#             "rides": [
#                 {
#                     "id": 4,
#                     "is_open": false,
#                     "last_updated": "2025-01-22T23:00:08.000Z",
#                     "name": "Autopia, presented by Avis",
#                     "wait_time": 0
#                 },
#                 {
#                     "id": 5,
#                     "is_open": true,
#                     "last_updated": "2025-01-22T23:00:08.000Z",
#                     "name": "Buzz Lightyear Laser Blast",
#                     "wait_time": 5
#                 },
#                 {
#                     "id": 2706,
#                     "is_open": false,
#                     "last_updated": "2025-01-22T23:00:08.000Z",
#                     "name": "Disneyland Railroad Discoveryland Station",
#                     "wait_time": 0
#                 },
#                 {
#                     "id": 6,
#                     "is_open": false,
#                     "last_updated": "2025-01-22T23:00:08.000Z",
#                     "name": "Les Myst\u00e8res du Nautilus",
#                     "wait_time": 0
#                 },
#                 {
#                     "id": 2707,
#                     "is_open": false,
#                     "last_updated": "2025-01-22T23:00:08.000Z",
#                     "name": "Mickey\u2019s PhilharMagic",
#                     "wait_time": 0
#                 },
#                 {
#                     "id": 7,
#                     "is_open": true,
#                     "last_updated": "2025-01-22T23:00:08.000Z",
#                     "name": "Orbitron\u00ae",
#                     "wait_time": 5
#                 },
#                 {
#                     "id": 9,
#                     "is_open": true,
#                     "last_updated": "2025-01-22T23:00:08.000Z",
#                     "name": "Star Tours: The Adventures Continue*",
#                     "wait_time": 5
#                 },
#                 {
#                     "id": 8,
#                     "is_open": true,
#                     "last_updated": "2025-01-22T23:00:08.000Z",
#                     "name": "Star Wars Hyperspace Mountain",
#                     "wait_time": 5
#                 },
#                 {
#                     "id": 7278,
#                     "is_open": true,
#                     "last_updated": "2025-01-22T23:00:08.000Z",
#                     "name": "Star Wars Hyperspace Mountain Single Rider",
#                     "wait_time": 0
#                 },
#                 {
#                     "id": 4573,
#                     "is_open": false,
#                     "last_updated": "2025-01-22T23:00:08.000Z",
#                     "name": "Welcome to Starport: A Star Wars Encounter",
#                     "wait_time": 0
#                 }
#             ]
#         },
#         {
#             "id": 19,
#             "name": "Fantasyland",
#             "rides": [
#                 {
#                     "id": 19,
#                     "is_open": false,
#                     "last_updated": "2025-01-22T23:00:08.000Z",
#                     "name": "\"it's a small world\"",
#                     "wait_time": 0
#                 },
#                 {
#                     "id": 14,
#                     "is_open": false,
#                     "last_updated": "2025-01-22T23:00:08.000Z",
#                     "name": "Alice's Curious Labyrinth",
#                     "wait_time": 0
#                 },
#                 {
#                     "id": 15,
#                     "is_open": false,
#                     "last_updated": "2025-01-22T23:00:08.000Z",
#                     "name": "Blanche-Neige et les Sept Nains\u00ae",
#                     "wait_time": 0
#                 },
#                 {
#                     "id": 17,
#                     "is_open": false,
#                     "last_updated": "2025-01-22T23:00:08.000Z",
#                     "name": "Casey Jr. \u2013 le Petit Train du Cirque",
#                     "wait_time": 0
#                 },
#                 {
#                     "id": 11,
#                     "is_open": false,
#                     "last_updated": "2025-01-22T23:00:08.000Z",
#                     "name": "Disneyland Railroad",
#                     "wait_time": 0
#                 },
#                 {
#                     "id": 2711,
#                     "is_open": false,
#                     "last_updated": "2025-01-22T23:00:08.000Z",
#                     "name": "Disneyland Railroad Fantasyland Station",
#                     "wait_time": 0
#                 },
#                 {
#                     "id": 18,
#                     "is_open": false,
#                     "last_updated": "2025-01-22T23:00:08.000Z",
#                     "name": "Dumbo the Flying Elephant",
#                     "wait_time": 0
#                 },
#                 {
#                     "id": 2710,
#                     "is_open": false,
#                     "last_updated": "2025-01-22T23:00:08.000Z",
#                     "name": "La Tani\u00e8re du Dragon",
#                     "wait_time": 0
#                 },
#                 {
#                     "id": 16,
#                     "is_open": false,
#                     "last_updated": "2025-01-22T23:00:08.000Z",
#                     "name": "Le Carrousel de Lancelot ",
#                     "wait_time": 0
#                 },
#                 {
#                     "id": 21,
#                     "is_open": false,
#                     "last_updated": "2025-01-22T23:00:08.000Z",
#                     "name": "Le Pays des Contes de F\u00e9es, presented by Vittel",
#                     "wait_time": 0
#                 },
#                 {
#                     "id": 23,
#                     "is_open": false,
#                     "last_updated": "2025-01-22T23:00:08.000Z",
#                     "name": "Les Voyages de Pinocchio",
#                     "wait_time": 0
#                 },
#                 {
#                     "id": 20,
#                     "is_open": false,
#                     "last_updated": "2025-01-22T23:00:08.000Z",
#                     "name": "Mad Hatter's Tea Cups",
#                     "wait_time": 0
#                 },
#                 {
#                     "id": 13,
#                     "is_open": false,
#                     "last_updated": "2025-01-22T23:00:08.000Z",
#                     "name": "Meet Mickey Mouse",
#                     "wait_time": 0
#                 },
#                 {
#                     "id": 22,
#                     "is_open": true,
#                     "last_updated": "2025-01-22T23:00:08.000Z",
#                     "name": "Peter Pan's Flight",
#                     "wait_time": 5
#                 },
#                 {
#                     "id": 24,
#                     "is_open": false,
#                     "last_updated": "2025-01-22T23:00:08.000Z",
#                     "name": "Princess Pavilion",
#                     "wait_time": 0
#                 }
#             ]
#         },
#         {
#             "id": 20,
#             "name": "Frontierland",
#             "rides": [
#                 {
#                     "id": 25,
#                     "is_open": false,
#                     "last_updated": "2025-01-22T23:00:08.000Z",
#                     "name": "Big Thunder Mountain",
#                     "wait_time": 0
#                 },
#                 {
#                     "id": 2714,
#                     "is_open": false,
#                     "last_updated": "2025-01-22T23:00:08.000Z",
#                     "name": "Disneyland Railroad Frontierland Depot",
#                     "wait_time": 0
#                 },
#                 {
#                     "id": 2713,
#                     "is_open": false,
#                     "last_updated": "2025-01-22T23:00:08.000Z",
#                     "name": "Frontierland Playground",
#                     "wait_time": 0
#                 },
#                 {
#                     "id": 26,
#                     "is_open": true,
#                     "last_updated": "2025-01-22T23:00:08.000Z",
#                     "name": "Phantom Manor",
#                     "wait_time": 5
#                 },
#                 {
#                     "id": 27,
#                     "is_open": false,
#                     "last_updated": "2025-01-22T23:00:08.000Z",
#                     "name": "River Rogue Keelboats",
#                     "wait_time": 0
#                 },
#                 {
#                     "id": 2712,
#                     "is_open": false,
#                     "last_updated": "2025-01-22T23:00:08.000Z",
#                     "name": "Rustler Roundup Shootin' Gallery",
#                     "wait_time": 0
#                 },
#                 {
#                     "id": 28,
#                     "is_open": false,
#                     "last_updated": "2025-01-22T23:00:08.000Z",
#                     "name": "Thunder Mesa Riverboat Landing",
#                     "wait_time": 0
#                 }
#             ]
#         },
#         {
#             "id": 21,
#             "name": "Main Street U.S.A",
#             "rides": [
#                 {
#                     "id": 2708,
#                     "is_open": false,
#                     "last_updated": "2025-01-22T23:00:08.000Z",
#                     "name": "Disneyland Railroad Main Street Station",
#                     "wait_time": 0
#                 },
#                 {
#                     "id": 12,
#                     "is_open": false,
#                     "last_updated": "2025-01-22T23:00:08.000Z",
#                     "name": "Main Street Vehicles",
#                     "wait_time": 0
#                 }
#             ]
#         }
#     ],
#     "rides": []
# }

# %%
parks = response["lands"]

data = []

for park in parks:
    print("Next Park")
    pprint(park["name"])
    rides = park["rides"]
    pprint(rides)
    #use a for loop to iterate through 'rides' and print the names
    for ride in rides:
        ride_info = {
            "Park": park["name"],
            "Ride Name": ride["name"],
            "Is Open": ride["is_open"],
            "Wait Time": ride["wait_time"],
            "Last Updated": ride["last_updated"]
        }
        data.append(ride_info)

        #here is where you would insert it as a dataframe or add to a csv that you have opened
        df = pd.DataFrame(data)
        #dataframe row 
        csv_filename = "DisneyParis_rides_data.csv"
        df.to_csv(csv_filename, index=False)
        # Create a DataFrame
        df = pd.DataFrame(data)
# Out:
# Next Park
# 'Adventureland'
# [{'id': 2702,
#   'is_open': False,
#   'last_updated': '2025-01-22T23:00:08.000Z',
#   'name': 'Adventure Isle',
#   'wait_time': 0},
#  {'id': 7306,
#   'is_open': True,
#   'last_updated': '2025-01-22T23:00:08.000Z',
#   'name': 'Indiana Jones and the Temple of Peril Single Rider',
#   'wait_time': 0},
#  {'id': 2,
#   'is_open': True,
#   'last_updated': '2025-01-22T23:00:08.000Z',
#   'name': 'Indiana Jones™ and the Temple of Peril',
#   'wait_time': 5},
#  {'id': 1,
#   'is_open': True,
#   'last_updated': '2025-01-22T23:00:08.000Z',
#   'name': 'La Cabane des Robinson',
#   'wait_time': 5},
#  {'id': 2703,
#   'is_open': False,
#   'last_updated': '2025-01-22T23:00:08.000Z',
#   'name': "Le Passage Enchanté d'Aladdin",
#   'wait_time': 0},
#  {'id': 2705,
#   'is_open': False,
#   'last_updated': '2025-01-22T23:00:08.000Z',
#   'name': 'Pirate Galleon',
#   'wait_time': 0},
#  {'id': 3,
#   'is_open': False,
#   'last_updated': '2025-01-22T23:00:08.000Z',
#   'name': 'Pirates of the Caribbean',
#   'wait_time': 0},
#  {'id': 2704,
#   'is_open': False,
#   'last_updated': '2025-01-22T23:00:08.000Z',
#   'name': "Pirates' Beach",
#   'wait_time': 0}]
# Next Park
# 'Discoveryland'
# [{'id': 4,
#   'is_open': False,
#   'last_updated': '2025-01-22T23:00:08.000Z',
#   'name': 'Autopia, presented by Avis',
#   'wait_time': 0},
#  {'id': 5,
#   'is_open': True,
#   'last_updated': '2025-01-22T23:00:08.000Z',
#   'name': 'Buzz Lightyear Laser Blast',
#   'wait_time': 5},
#  {'id': 2706,
#   'is_open': False,
#   'last_updated': '2025-01-22T23:00:08.000Z',
#   'name': 'Disneyland Railroad Discoveryland Station',
#   'wait_time': 0},
#  {'id': 6,
#   'is_open': False,
#   'last_updated': '2025-01-22T23:00:08.000Z',
#   'name': 'Les Mystères du Nautilus',
#   'wait_time': 0},
#  {'id': 2707,
#   'is_open': False,
#   'last_updated': '2025-01-22T23:00:08.000Z',
#   'name': 'Mickey’s PhilharMagic',
#   'wait_time': 0},
#  {'id': 7,
#   'is_open': True,
#   'last_updated': '2025-01-22T23:00:08.000Z',
#   'name': 'Orbitron®',
#   'wait_time': 5},
#  {'id': 9,
#   'is_open': True,
#   'last_updated': '2025-01-22T23:00:08.000Z',
#   'name': 'Star Tours: The Adventures Continue*',
#   'wait_time': 5},
#  {'id': 8,
#   'is_open': True,
#   'last_updated': '2025-01-22T23:00:08.000Z',
#   'name': 'Star Wars Hyperspace Mountain',
#   'wait_time': 5},
#  {'id': 7278,
#   'is_open': True,
#   'last_updated': '2025-01-22T23:00:08.000Z',
#   'name': 'Star Wars Hyperspace Mountain Single Rider',
#   'wait_time': 0},
#  {'id': 4573,
#   'is_open': False,
#   'last_updated': '2025-01-22T23:00:08.000Z',
#   'name': 'Welcome to Starport: A Star Wars Encounter',
#   'wait_time': 0}]
# Next Park
# 'Fantasyland'
# [{'id': 19,
#   'is_open': False,
#   'last_updated': '2025-01-22T23:00:08.000Z',
#   'name': '"it\'s a small world"',
#   'wait_time': 0},
#  {'id': 14,
#   'is_open': False,
#   'last_updated': '2025-01-22T23:00:08.000Z',
#   'name': "Alice's Curious Labyrinth",
#   'wait_time': 0},
#  {'id': 15,
#   'is_open': False,
#   'last_updated': '2025-01-22T23:00:08.000Z',
#   'name': 'Blanche-Neige et les Sept Nains®',
#   'wait_time': 0},
#  {'id': 17,
#   'is_open': False,
#   'last_updated': '2025-01-22T23:00:08.000Z',
#   'name': 'Casey Jr. – le Petit Train du Cirque',
#   'wait_time': 0},
#  {'id': 11,
#   'is_open': False,
#   'last_updated': '2025-01-22T23:00:08.000Z',
#   'name': 'Disneyland Railroad',
#   'wait_time': 0},
#  {'id': 2711,
#   'is_open': False,
#   'last_updated': '2025-01-22T23:00:08.000Z',
#   'name': 'Disneyland Railroad Fantasyland Station',
#   'wait_time': 0},
#  {'id': 18,
#   'is_open': False,
#   'last_updated': '2025-01-22T23:00:08.000Z',
#   'name': 'Dumbo the Flying Elephant',
#   'wait_time': 0},
#  {'id': 2710,
#   'is_open': False,
#   'last_updated': '2025-01-22T23:00:08.000Z',
#   'name': 'La Tanière du Dragon',
#   'wait_time': 0},
#  {'id': 16,
#   'is_open': False,
#   'last_updated': '2025-01-22T23:00:08.000Z',
#   'name': 'Le Carrousel de Lancelot ',
#   'wait_time': 0},
#  {'id': 21,
#   'is_open': False,
#   'last_updated': '2025-01-22T23:00:08.000Z',
#   'name': 'Le Pays des Contes de Fées, presented by Vittel',
#   'wait_time': 0},
#  {'id': 23,
#   'is_open': False,
#   'last_updated': '2025-01-22T23:00:08.000Z',
#   'name': 'Les Voyages de Pinocchio',
#   'wait_time': 0},
#  {'id': 20,
#   'is_open': False,
#   'last_updated': '2025-01-22T23:00:08.000Z',
#   'name': "Mad Hatter's Tea Cups",
#   'wait_time': 0},
#  {'id': 13,
#   'is_open': False,
#   'last_updated': '2025-01-22T23:00:08.000Z',
#   'name': 'Meet Mickey Mouse',
#   'wait_time': 0},
#  {'id': 22,
#   'is_open': True,
#   'last_updated': '2025-01-22T23:00:08.000Z',
#   'name': "Peter Pan's Flight",
#   'wait_time': 5},
#  {'id': 24,
#   'is_open': False,
#   'last_updated': '2025-01-22T23:00:08.000Z',
#   'name': 'Princess Pavilion',
#   'wait_time': 0}]
# Next Park
# 'Frontierland'
# [{'id': 25,
#   'is_open': False,
#   'last_updated': '2025-01-22T23:00:08.000Z',
#   'name': 'Big Thunder Mountain',
#   'wait_time': 0},
#  {'id': 2714,
#   'is_open': False,
#   'last_updated': '2025-01-22T23:00:08.000Z',
#   'name': 'Disneyland Railroad Frontierland Depot',
#   'wait_time': 0},
#  {'id': 2713,
#   'is_open': False,
#   'last_updated': '2025-01-22T23:00:08.000Z',
#   'name': 'Frontierland Playground',
#   'wait_time': 0},
#  {'id': 26,
#   'is_open': True,
#   'last_updated': '2025-01-22T23:00:08.000Z',
#   'name': 'Phantom Manor',
#   'wait_time': 5},
#  {'id': 27,
#   'is_open': False,
#   'last_updated': '2025-01-22T23:00:08.000Z',
#   'name': 'River Rogue Keelboats',
#   'wait_time': 0},
#  {'id': 2712,
#   'is_open': False,
#   'last_updated': '2025-01-22T23:00:08.000Z',
#   'name': "Rustler Roundup Shootin' Gallery",
#   'wait_time': 0},
#  {'id': 28,
#   'is_open': False,
#   'last_updated': '2025-01-22T23:00:08.000Z',
#   'name': 'Thunder Mesa Riverboat Landing',
#   'wait_time': 0}]
# Next Park
# 'Main Street U.S.A'
# [{'id': 2708,
#   'is_open': False,
#   'last_updated': '2025-01-22T23:00:08.000Z',
#   'name': 'Disneyland Railroad Main Street Station',
#   'wait_time': 0},
#  {'id': 12,
#   'is_open': False,
#   'last_updated': '2025-01-22T23:00:08.000Z',
#   'name': 'Main Street Vehicles',
#   'wait_time': 0}]
